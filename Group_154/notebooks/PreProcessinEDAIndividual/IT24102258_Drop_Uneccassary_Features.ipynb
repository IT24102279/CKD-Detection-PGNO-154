# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import pandas as pd

pd.set_option("display.max_columns", None)


import matplotlib
matplotlib.use('Agg')  # Use Agg backend if full matplotlib is imported

import matplotlib.pyplot as plt
plt.switch_backend('Agg')  # if only plt is imported

get_ipython().run_line_magic('matplotlib', 'inline')

import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

RANDOM_SEED = 42

# Set default style for seaborn
sns.set(style='whitegrid')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data Loading
data_path = '/content/drive/MyDrive/V5/CKD_India.csv'
df = pd.read_csv(data_path, delimiter=',', encoding='ascii')

print('Dataset loaded successfully.')
print('Shape:', df.shape)
# Out:
# Dataset loaded successfully.
# Shape: (1100, 26)

# %%
new_df = df.copy()

# %%
new_df.columns = [
    'id','age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
    'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
    'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
    'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count',
    'red_blood_cell_count', 'hypertension', 'diabetes_mellitus',
    'coronary_artery_disease', 'appetite', 'peda_edema', 'anemia', 'class'
]

# %% [markdown]
# ## **1.Drop unecasasry columns**

# %%
#before
df.head()
# Out:
#     id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 0  102  17.0  60.0  1.010  0.0  0.0     NaN  normal  notpresent  notpresent
# 1  348  38.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 2  270  23.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 3  106  50.0  90.0    NaN  NaN  NaN     NaN     NaN  notpresent  notpresent
# 4   71  46.0  60.0  1.010  1.0  0.0  normal  normal  notpresent  notpresent
#
#      bgr     bu   sc    sod  pot  hemo pcv     wc   rc  htn   dm cad appet  \
# 0   92.0   32.0  2.1  141.0  4.2  13.9  52   7000  NaN   no   no  no  good
# 1   99.0   19.0  0.5  147.0  3.5  13.6  44   7300  6.4   no   no  no  good
# 2  111.0   34.0  1.1  145.0  4.0  14.3  41   7200  5.0   no   no  no  good
# 3   89.0  118.0  6.1  127.0  4.4   6.0  17   6500  NaN  yes  yes  no  good
# 4  163.0   92.0  3.3  141.0  4.0   9.8  28  14600  3.2  yes  yes  no  good
#
#     pe  ane classification
# 0   no   no            ckd
# 1   no   no         notckd
# 2   no   no         notckd
# 3  yes  yes            ckd
# 4   no   no            ckd

# %%
new_df = new_df.drop('id', axis=1)
print('Column id dropped successfully.')
print('Shape after dropping id:', new_df.shape)
new_df.head()
# Out:
# Column id dropped successfully.
# Shape after dropping id: (1100, 25)
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  17.0            60.0             1.010      0.0    0.0             NaN
# 1  38.0            80.0             1.020      0.0    0.0          normal
# 2  23.0            80.0             1.025      0.0    0.0          normal
# 3  50.0            90.0               NaN      NaN    NaN             NaN
# 4  46.0            60.0             1.010      1.0    0.0          normal
#
#   pus_cell pus_cell_clumps    bacteria  blood_glucose_random  blood_urea  \
# 0   normal      notpresent  notpresent                  92.0        32.0
# 1   normal      notpresent  notpresent                  99.0        19.0
# 2   normal      notpresent  notpresent                 111.0        34.0
# 3      NaN      notpresent  notpresent                  89.0       118.0
# 4   normal      notpresent  notpresent                 163.0        92.0
#
#    serum_creatinine  sodium  potassium  haemoglobin packed_cell_volume  \
# 0               2.1   141.0        4.2         13.9                 52
# 1               0.5   147.0        3.5         13.6                 44
# 2               1.1   145.0        4.0         14.3                 41
# 3               6.1   127.0        4.4          6.0                 17
# 4               3.3   141.0        4.0          9.8                 28
#
#   white_blood_cell_count red_blood_cell_count hypertension diabetes_mellitus  \
# 0                   7000                  NaN           no                no
# 1                   7300                  6.4           no                no
# 2                   7200                  5.0           no                no
# 3                   6500                  NaN          yes               yes
# 4                  14600                  3.2          yes               yes
#
#   coronary_artery_disease appetite peda_edema anemia   class
# 0                      no     good         no     no     ckd
# 1                      no     good         no     no  notckd
# 2                      no     good         no     no  notckd
# 3                      no     good        yes    yes     ckd
# 4                      no     good         no     no     ckd
